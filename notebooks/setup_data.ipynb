# %%
from icxcca import *
import pynapple as nap
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

import logging

logging.basicConfig(level=logging.INFO)

data_filenames = [
    "2022_04_12_0002.csv",
    "2022_04_12_0004.csv",
    "2022_04_13_0005.csv",
    "2022_04_14_0001.csv",
    "2022_04_14_0002.csv",
    "2022_04_14_0003.csv",
    "2022_04_28_0012.csv",
    "2022_04_28_0015.csv",
    "2022_04_28_0016.csv",
]

data_dir = "../data/processed"

data_filepaths = [Path(data_dir) / Path(f) for f in data_filenames]

# %%
data_filename = "../data/processed/2022_04_12_0002.csv"
dm = DataManager(data_filename)
fig, _ = dm.plot(autosave=True)
# Out:
# INFO:icxcca.data:Initializing DataManager for ../data/processed/2022_04_12_0002.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_12_0002.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_12_0002.csv
# INFO:icxcca.data:Loaded 50 features from ..\data\processed\2022_04_12_0002.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_12_0002.csv with features_per_subplot=2, autosave=True
# INFO:icxcca.data:Plotting 50 features across 25 subplots
# INFO:icxcca.data:Using shared y-limits: [-120.8496, 190.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Derived figure filename 2022_04_12_0002.png from ..\data\processed\2022_04_12_0002.csv
# INFO:icxcca.data:Saving figure to 2022_04_12_0002.png

# %%
# for fp in data_filepaths:
#     dm = DataManager(fp)
#     fig, _ = dm.plot()
#     name = Path(fp).stem
#     print(name)
#     fig.savefig(f"{name}_processed.png")

# %%
# look at the same interval for all files

# interval = nap.IntervalSet(start=1.0, end=2.0, time_units="s")
# for data_filename in files:
#     data = get_data(data_filename).restrict(interval)
#     plt.figure()
#     plt.plot(data.t, data.d, marker="")
#     plt.title(data_filename)
#     plt.xlabel("Time (s)")
#     plt.show()

# %%
# save plots and npz files for restricted time

interval = nap.IntervalSet(start=1.0, end=2.0, time_units="s")
for fp in data_filepaths:
    dm = DataManager(fp)
    dm.data = dm.data.restrict(interval)
    fig, _ = dm.plot()
    name = Path(fp).stem
    fig.savefig(f"../figures/{name}_trunc.png")
    npz_filepath = f"../data/npz/{name}_trunc.npz"
    dm.write_npz(npz_filepath)
# Out:
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_12_0002.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_12_0002.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_12_0002.csv
# INFO:icxcca.data:Loaded 50 features from ..\data\processed\2022_04_12_0002.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_12_0002.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 50 features across 25 subplots
# INFO:icxcca.data:Using shared y-limits: [-120.8496, 190.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_12_0002_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_12_0002_trunc.npz
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_12_0004.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_12_0004.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_12_0004.csv
# INFO:icxcca.data:Loaded 40 features from ..\data\processed\2022_04_12_0004.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_12_0004.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 40 features across 20 subplots
# INFO:icxcca.data:Using shared y-limits: [-94.2688, 140.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_12_0004_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_12_0004_trunc.npz
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_13_0005.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_13_0005.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_13_0005.csv
# INFO:icxcca.data:Loaded 50 features from ..\data\processed\2022_04_13_0005.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_13_0005.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 50 features across 25 subplots
# INFO:icxcca.data:Using shared y-limits: [-109.0393, 190.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_13_0005_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_13_0005_trunc.npz
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_14_0001.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_14_0001.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_14_0001.csv
# INFO:icxcca.data:Loaded 48 features from ..\data\processed\2022_04_14_0001.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_14_0001.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 48 features across 24 subplots
# INFO:icxcca.data:Using shared y-limits: [-111.1145, 180.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_14_0001_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_14_0001_trunc.npz
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_14_0002.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_14_0002.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_14_0002.csv
# INFO:icxcca.data:Loaded 60 features from ..\data\processed\2022_04_14_0002.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_14_0002.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 60 features across 30 subplots
# INFO:icxcca.data:Using shared y-limits: [-114.7461, 240.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_14_0002_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_14_0002_trunc.npz
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_14_0003.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_14_0003.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_14_0003.csv
# INFO:icxcca.data:Loaded 60 features from ..\data\processed\2022_04_14_0003.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_14_0003.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 60 features across 30 subplots
# INFO:icxcca.data:Using shared y-limits: [-102.2644, 240.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_14_0003_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_14_0003_trunc.npz
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_28_0012.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_28_0012.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_28_0012.csv
# INFO:icxcca.data:Loaded 20 features from ..\data\processed\2022_04_28_0012.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_28_0012.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 20 features across 10 subplots
# INFO:icxcca.data:Using shared y-limits: [-97.96143, 40.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_28_0012_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_28_0012_trunc.npz
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_28_0015.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_28_0015.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_28_0015.csv
# INFO:icxcca.data:Loaded 28 features from ..\data\processed\2022_04_28_0015.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_28_0015.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 28 features across 14 subplots
# INFO:icxcca.data:Using shared y-limits: [-92.28516, 80.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_28_0015_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_28_0015_trunc.npz
# INFO:icxcca.data:Initializing DataManager for ..\data\processed\2022_04_28_0016.csv
# INFO:icxcca.data:Loading data from ..\data\processed\2022_04_28_0016.csv
# INFO:icxcca.data:Detected CSV header row 0 for ..\data\processed\2022_04_28_0016.csv
# INFO:icxcca.data:Loaded 60 features from ..\data\processed\2022_04_28_0016.csv
# INFO:icxcca.data:Plot requested for ..\data\processed\2022_04_28_0016.csv with features_per_subplot=2, autosave=False
# INFO:icxcca.data:Plotting 60 features across 30 subplots
# INFO:icxcca.data:Using shared y-limits: [-82.55005, 240.0]
# INFO:icxcca.data:Created feature plot figure
# INFO:icxcca.data:Writing pynapple data to ..\data\npz\2022_04_28_0016_trunc.npz
# INFO:icxcca.data:Wrote pynapple data to ..\data\npz\2022_04_28_0016_trunc.npz
